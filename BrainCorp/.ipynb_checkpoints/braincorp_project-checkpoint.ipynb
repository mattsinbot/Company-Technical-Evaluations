# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
PATH = "/home/nobug-ros/Desktop/cpp_practice/BrainCorp/find_phone/"
img1 = cv2.imread(PATH+'0.jpg')
# img2 = mpimg.imread('0'+'.jpg')
plt.imshow(img1)
plt.show()

# %%
print(img1.shape)
# Out:
# (326, 490, 3)

# %%
print(img2.shape)
# Out:
# (326, 490, 3)

# %%
camera_img = img1[22:65,385:431,:]
cv2.imwrite('0cam.jpg',camera_img)
plt.imshow(camera_img)
plt.show()
